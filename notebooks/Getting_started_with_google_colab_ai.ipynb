# %% [markdown]
# <a href="https://colab.research.google.com/github/tahsinislamofficial-web/New-project-IG/blob/main/notebooks/Getting_started_with_google_colab_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install PyTorch first
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118 -q

# Run the video generator
exec(open("ai_video_generator.py").read())
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# 🟡 Google Colab detected!
#    For quick use, call: colab_generate('your prompt here')
#    Or run main() for the full menu.
#
# Enter your video prompt (or press Enter for menu): A girl with a flower giving to a boy
#
# ════════════════════════════════════════════════════════════
#    🎬  AI VIDEO GENERATOR  —  CogVideoX Open Source
#    Free alternative to Kling 2.6
# ════════════════════════════════════════════════════════════
#    ✅ GPU Detected : Tesla T4
#    💾 VRAM         : 15.6 GB
# ════════════════════════════════════════════════════════════
#
# 🔄 Loading model: THUDM/CogVideoX-2b
#    (First run downloads ~8GB — please wait...)
# ...
